# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import font_manager, rc
font_path = "./malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
df=pd.read_excel('국가별_원유수입_20230225172627.xlsx')
# df.to_excel('국가별_원유수입_20230225172627.xlsx', index=False)

# %%
df1=df.iloc[2:,1:]

# %%
df1=df1.rename(columns={'국가별(2)':'연도'})
df1
# Out:
#          연도    1998    1999    2000    2001    2002    2003    2004    2005  \
# 2        중국   24192    3872    3881    2083    3696    7096    8602    7061
# 3       필리핀       -       -       -       -    1262       -     302       -
# 4        태국    1991       -     709       -    2741     936    2621    2345
# 5     말레이지아   18156   19988   17732   19838   14247   11101   13785   13037
# 6     인도네시아   33599   41726   36762   45228   42457   33672   38104   37703
# 7     방글라데시       -       -       -       -       -       -       -       -
# 8        인도     224       -       -       -       -       -       -       -
# 9      브루나이   13786    8045    8649    9631   11508   11247   10897   10558
# 10       호주   14252   15495   34990   32879   39552   25396   32068   31879
# 11     뉴질랜드       -       -       -       -       -       -       -       -
# 12      베트남    1811     628       -     470     437       -    1390       -
# ...

# %%
df1=df1.set_index('연도')
df1
# Out:
#            1998    1999    2000    2001    2002    2003    2004    2005  \
# 연도
# 중국        24192    3872    3881    2083    3696    7096    8602    7061
# 필리핀           -       -       -       -    1262       -     302       -
# 태국         1991       -     709       -    2741     936    2621    2345
# 말레이지아     18156   19988   17732   19838   14247   11101   13785   13037
# 인도네시아     33599   41726   36762   45228   42457   33672   38104   37703
# 방글라데시         -       -       -       -       -       -       -       -
# 인도          224       -       -       -       -       -       -       -
# 브루나이      13786    8045    8649    9631   11508   11247   10897   10558
# 호주        14252   15495   34990   32879   39552   25396   32068   31879
# 뉴질랜드          -       -       -       -       -       -       -       -
# 베트남        1811     628       -     470     437       -    1390       -
# 미얀마           -       -       -    1218    1687       -       -     388
# ...

# %%
df1.drop(['소계'],inplace=True)

# %%
df1=df1.replace('-',np.NaN)
df1T=df1.T

# %%
missing_df1T = df1T.isnull()
for col in missing_df1T.columns:
    missing_count=missing_df1T[col].value_counts()
    try:
        print(col,':', missing_count[True])
    except:
        print(col, ':', 0)
# Out:
# 중국 : 10
# 필리핀 : 7
# 태국 : 6
# 말레이지아 : 0
# 인도네시아 : 0
# 방글라데시 : 23
# 인도 : 23
# 브루나이 : 1
# 호주 : 0
# 뉴질랜드 : 17
# 베트남 : 4
# 미얀마 : 17
# 파푸아뉴기니 : 17
# 러시아 : 0
# 카자흐스탄 : 14
# 아제르바이젠 : 20
# 튀니지 : 23
# 알제리 : 9
# 리비아 : 15
# 이집트 : 15
# 앙골라 : 10
# 카메룬 : 9
# 콩고 : 6
# 가봉 : 5
# 나이지리아 : 7
# 수단 : 11
# 적도기니아 : 2
# 캐나다 : 16
# 미국 : 13
# 멕시코 : 17
# 베네주엘라 : 21
# 브라질 : 14
# 에쿠아도르 : 9
# 페루 : 19
# 아르헨티나 : 18
# 콜롬비아 : 16
# 볼리비아 : 23
# 이란 : 2
# 이라크 : 0
# 쿠웨이트 : 0
# 카타르 : 0
# 아랍에미레이트 : 0
# 사우디아라비아 : 0
# 예멘 : 12
# 오만 : 0
# 중립지대 : 4
# 노르웨이 : 9
# 영국 : 10

# %%
oil_incom=df1T.dropna(axis=1, thresh=5)
oil_incom=df1T.dropna(axis=1, thresh=10)
oil_incom=df1T.dropna(axis=1, thresh=15)
oil_incom=df1T.dropna(axis=1, thresh=20)
oil_incom
# Out:
# 연도      말레이지아    인도네시아     브루나이       호주     베트남      러시아    적도기니아        이란  \
# 1998  18156.0  33599.0  13786.0  14252.0  1811.0   3539.0    915.0   67502.0
# 1999  19988.0  41726.0   8045.0  15495.0   628.0   3763.0   4069.0   81944.0
# 2000  17732.0  36762.0   8649.0  34990.0     NaN   9946.0   1995.0   81251.0
# 2001  19838.0  45228.0   9631.0  32879.0   470.0  18685.0    956.0   80413.0
# 2002  14247.0  42457.0  11508.0  39552.0   437.0  15049.0   3879.0   51512.0
# 2003  11101.0  33672.0  11247.0  25396.0     NaN   7025.0   2324.0   63682.0
# 2004  13785.0  38104.0  10897.0  32068.0  1390.0   8517.0   1542.0   64974.0
# 2005  13037.0  37703.0  10558.0  31879.0     NaN   8305.0    946.0   70767.0
# 2006  12747.0  23359.0  13210.0  34652.0     NaN  13973.0    680.0   75058.0
# 2007  12991.0  17603.0   9224.0  39101.0  1724.0  38129.0   1365.0   85793.0
# 2008  11155.0  16308.0  10644.0  34499.0  1603.0  23463.0      NaN   73016.0
# ...

# %%
oil_incom=oil_incom.fillna(method='ffill')
oil_incom=oil_incom.T

# %%
oil_incom.columns
# Out:
# Index(['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
# col_years =list(map(str, range(1998,2022)))
# oil_incom= oil_incom.loc[['베트남','러시아','오만'],col_years]

# plt.style.use('ggplot')

# fig = plt.figure(figsize=(20,10))
# ax1 = fig.add_subplot(1,1,1)

# ax1.plot(col_years, oil_incom.loc['베트남',:], marker='o', markerfacecolor='red', markersize=7,color='firebrick', linewidth=2, label='베트남')
# ax1.plot(col_years, oil_incom.loc['러시아',:], marker='o', markerfacecolor='blue', markersize=7,color='skyblue', linewidth=2, label='러시아')
# ax1.plot(col_years, oil_incom.loc['오만',:], marker='o', markerfacecolor='gray', markersize=7,color='black', linewidth=2, label='오만')

# ax1.legend(loc='best')

# ax1.set_title('국가별 석유 수입', size = 15)

# ax1.tick_params(axis="x", labelsize= 8)
# ax1.tick_params(axis="y", labelsize= 8)
#==========================================================================================================================================================#
sns.set_style('whitegrid')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

sns.barplot(x='')


plt.show()

# %%
# Out:
# range
